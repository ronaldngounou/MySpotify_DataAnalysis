# %% [markdown]
# # My Spotify Data Analyis

# %% [markdown]
# # 1. Motivation

# %% [markdown]
# # 2. Data Collection

# %% [markdown]
# I have asked spotify to send the data. The interesting files I will use are:
# 1. Playlist1 : A summary of the playlist created or saved, and any song saved.
# 2. StreamingHistory0 : A list of items (songs, videos, and podcasts) listened to or watched in the past year.
# 3. YourLibrary : A summary of the content saved in My Library
# 4. SearchQueries : A list of searches I made.

# %% [markdown]
# # 3. Data Cleaning

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import math 
from matplotlib import pyplot  
import matplotlib.pyplot as plt

# %matplotlib inline


import plotly
import plotly.offline as py
import plotly.graph_objs as go
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0

import cufflinks as cf

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

cf.go_offline()

import xlsxwriter

from mpl_toolkits import mplot3d

np.seterr(divide='ignore', invalid='ignore')
# Out:
# 5.8.0
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
path_playlist = r"C:Users\Admin\OneDrive - HESSO\PERSO\AI ML Deep Learning\Projects\20220921 Spotify Data Analysis\mydata\Playlist1.json"
df_playlist = pd.read_json(path_playlist , orient = "index")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Admin\OneDrive - HESSO\PERSO\AI ML Deep Learning\Projects\20220921 Spotify Data Analysis\Main.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/OneDrive%20-%20HESSO/PERSO/AI%20ML%20Deep%20Learning/Projects/20220921%20Spotify%20Data%20Analysis/Main.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> df_playlist = pd.read_json(r"C:Users\Admin\OneDrive - HESSO\PERSO\AI ML Deep Learning\Projects\20220921 Spotify Data Analysis\mydata\Playlist1.json" , orient = "index")
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# ...

# %%
df_history = pd.read_json(r"C:\Users\Admin\OneDrive - HESSO\PERSO\AI ML Deep Learning\Projects\20220921 Spotify Data Analysis\mydata\StreamingHistory0.json", orient = 'records')
df_history
# Out:
#                endTime          artistName  \
# 0     2021-09-24 12:43        Kendji Girac
# 1     2021-09-24 12:44       Matt Champion
# 2     2021-09-24 12:46               Aminé
# 3     2021-09-24 12:49             Berhana
# 4     2021-09-24 12:52               Jaden
# ...                ...                 ...
# 5618  2022-09-24 03:10         MOTIVACTION
# 5619  2022-09-24 03:13  HeartBlend Podcast
# 5620  2022-09-24 03:15  HeartBlend Podcast
# 5621  2022-09-24 03:20  HeartBlend Podcast
# 5622  2022-09-24 03:25  HeartBlend Podcast
#
#                                               trackName  msPlayed
# 0                                         Dans mes bras    167772
# 1                                                 Fangs     80015
# 2                                            REEL IT IN    121346
# 3                                               Wildin'    139613
# 4                                                  SOHO    208493
# ...

# %%
df_MyLibrary = pd.read_json(r"C:\Users\Admin\OneDrive - HESSO\PERSO\AI ML Deep Learning\Projects\20220921 Spotify Data Analysis\mydata\YourLibrary.json", orient = 'index')
df_MyLibrary
# Out:
#                                                              0    \
# tracks         {'artist': 'Royce Da 5'9"', 'album': 'Book of ...
# albums         {'artist': 'Buddy', 'album': 'Harlan & Alondra...
# shows          {'name': '16 Minutes News by a16z', 'publisher...
# episodes       {'name': 'The Racist Theory Behind So Many Mas...
# bannedTracks   {'artist': 'Belly', 'album': 'What You Want (f...
# artists        {'name': 'Akira The Don', 'uri': 'spotify:arti...
# bannedArtists                                               None
# other                                                       None
#
#                                                              1    \
# tracks         {'artist': 'Tory Lanez', 'album': 'I Told You'...
# albums         {'artist': 'Mick Jenkins', 'album': 'Pieces of...
# shows          {'name': '6 Minute English', 'publisher': 'BBC...
# episodes       {'name': 'The Sunday Read: ‘How Many Billionai...
# ...

# %%
df_SearchQueries = pd.read_json(r"C:\Users\Admin\OneDrive - HESSO\PERSO\AI ML Deep Learning\Projects\20220921 Spotify Data Analysis\mydata\SearchQueries.json")
